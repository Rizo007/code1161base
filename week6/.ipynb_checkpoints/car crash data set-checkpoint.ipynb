# %%
import os
import geopandas as gp
import shapely as shp
import fiona
import matplotlib
import matplotlib.pyplot as plt
import matplotlib.cm as cm
import operator as o
import numpy as np
import pandas as pd
import scipy as sp
import plotly.plotly as py
import plotly.tools as tls
tls.set_credentials_file(username='chidzzy', api_key='mmFpRWTJIMYJ0aEaFi8w')
import plotly.graph_objs as go
from IPython.display import Image
from plotly.grid_objs import Grid, Column
from plotly.tools import FigureFactory as FF 
import time

# %%
# %matplotlib inline
plt.rcParams['figure.figsize'] = (20, 10)

# %%
saved_style_state = matplotlib.rcParams.copy()

# %%
if os.path.isfile("Fatal_Crashes_Apr_2017.csv"):
    filepath = "Fatal_Crashes_Apr_2017.csv"
    print("loading from file")
else:
    filepath = "https://bitre.gov.au/statistics/safety/files/Fatal_Crashes_Apr_2017.csv"
    print("loading from the internet")

crash_data = pd.read_csv(filepath)
print("done")
# Out:
# loading from the internet
# done

# %%
if os.path.isfile("Fatalities_Apr_2017_II.csv"):
    filepath = "Fatalities_Apr_2017_II.csv"
    print("loading from file")
else:
    filepath = "https://bitre.gov.au/statistics/safety/files/Fatalities_Apr_2017_II.csv"
    print("loading from the internet")

Fatality_data = pd.read_csv(filepath)
print("done")
# Out:
# loading from the internet
# done

# %%
crash_data.head()
# Out:
#          CrashID State  Day  Month  Year Hour Minute         Crash_Type  \
# 0  3201701010001   QLD    1      1  2017    0      0         Pedestrian
# 1  5201701010001    WA    1      1  2017   16     30   Multiple vehicle
# 2  5201701010002    WA    1      1  2017   17     14   Multiple vehicle
# 3  3201701020002   QLD    2      1  2017    3      0         Pedestrian
# 4  1201701020002   NSW    2      1  2017   13     15   Multiple vehicle
#
#    Number_of_Fatalities Bus_Involvement Heavy_Rigid_Truck_Involvement  \
# 0                     1              No                            No
# 1                     1              No                            No
# 2                     1              No                            No
# 3                     1              No                            No
# 4                     1              No                            No
#
#   Articulated_Truck_Involvement Speed_Limit
# 0                            No          50
# 1                            No         100
# 2                            No          70
# 3                            No         100
# 4                            No          80

# %%
Fatality_data.head()
# Out:
#          CrashID State  Day    Month  Year  Hour  Minute        Crash_Type  \
# 0  3201701010001   QLD    1  January  2017     0       0        Pedestrian
# 1  5201701010001    WA    1  January  2017    16      30  Multiple vehicle
# 2  5201701010002    WA    1  January  2017    17      14  Multiple vehicle
# 3  3201701020002   QLD    2  January  2017     3       0        Pedestrian
# 4  1201701020002   NSW    2  January  2017    13      15  Multiple vehicle
#
#   Bus_Involvement Heavy_Rigid_Truck_Involvement Articulated_Truck_Involvement  \
# 0              No                            No                            No
# 1              No                            No                            No
# 2              No                            No                            No
# 3              No                            No                            No
# 4              No                            No                            No
#
#    Speed_Limit         Road_User  Gender  Age
# 0           50        Pedestrian  Female   64
# 1          100  Motorcycle rider    Male   21
# 2           70            Driver    Male   25
# 3          100        Pedestrian  Female   30
# 4           80  Motorcycle rider    Male   26

# %%
crash_data.columns
# Out:
# Index(['CrashID', 'State', 'Day', 'Month', 'Year', 'Hour', 'Minute',
#        'Crash_Type', 'Number_of_Fatalities', 'Bus_Involvement',
#        'Heavy_Rigid_Truck_Involvement', 'Articulated_Truck_Involvement',
#        'Speed_Limit'],
#       dtype='object')

# %%
row_one = crash_data.iloc[42863]
row_one
# Out:
# CrashID                              2198912310681
# State                                          VIC
# Day                                             31
# Month                                           12
# Year                                          1989
# Hour                                            12
# Minute                                          35
# Crash_Type                        Multiple vehicle
# Number_of_Fatalities                             1
# Bus_Involvement                                 No
# Heavy_Rigid_Truck_Involvement
# Articulated_Truck_Involvement                   No
# Speed_Limit                                     60
# Name: 42863, dtype: object

# %%
Fatality_data["Year"].hist()

# %%
Fatality_data["State"].value_counts().plot(kind="bar")

# %%
Fatality_data["Gender"].value_counts().plot(kind="bar")

# %%
# file:///C:/Users/chris/Desktop/Plot%201.html
# file:///C:/Users/chris/Desktop/Plot%202.html
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-65-5af36c6e818d> in <module>()
#       1 # file:///C:/Users/chris/Desktop/Plot%201.html
#       2 # file:///C:/Users/chris/Desktop/Plot%202.html
# ----> 3 table = FF.create_heatmap(Fatality_data.head(10))
#       4 py.iplot(table, filename='animations-gapminder-data-preview')
#
# AttributeError: type object 'FigureFactory' has no attribute 'create_heatmap'

# %%
Fatality_data["Age"].value_counts().plot(kind="bar")

# %%
table = FF.create_table(Fatality_data.head(10))
py.iplot(table, filename='animations-gapminder-data-preview')plotly.__version__
# Out:
# <iframe id="igraph" scrolling="no" style="border:none;" seamless="seamless" src="https://plot.ly/~chidzzy/2.embed" height="380px" width="100%"></iframe>

# %%
Years_from_col = set(Fatality_data['Year'])
Years_ints = sorted(list(Years_from_col))
Years = [str(Year) for Year in Years_ints]

# make list of states
state = []
for state in Fatality_data['State']:
    if state not in state: 
        state.append(state)

columns = []
# make grid
for Year in Years:
    for state in state:
        Fatality_data_by_year = Fatality_data[Fatality_data['Year'] == int(Year)]
        Fatality_data_by_year_and_state = Fatality_data_by_year[Fatality_data_by_year['State'] == state]
        for col_name in Fatality_data_by_year_and_state:
            # each column name is unique
            column_name = '{Year}_{state}_{header}_gapminder_grid'.format(
                Year=Year, state=state, header=col_name
            )
            a_column = Column(list(Fatality_data_by_year_and_cont[col_name]), column_name)
            columns.append(a_column)

# upload grid
grid = Grid(columns)
url = py.grid_ops.upload(grid, 'gapminder_grid'+str(time.time()), auto_open=False)
url
# Out:
# 'https://plot.ly/~chidzzy/4/'

# %%
figure = {
    'data': [],
    'layout': {},
    'frames': [],
    'config': {'scrollzoom': True}
}

# fill in most of layout
figure['layout']['xaxis'] = {'range': [30, 85], 'title': 'Age', 'gridcolor': '#FFFFFF'}
figure['layout']['yaxis'] = {'title': 'Gender', 'type': 'log', 'gridcolor': '#FFFFFF'}
figure['layout']['hovermode'] = 'closest'
figure['layout']['plot_bgcolor'] = 'rgb(223, 232, 243)'

# %%
figure['layout']['slider'] = {
    'args': [
        'slider.value', {
            'duration': 400,
            'ease': 'cubic-in-out'
        }
    ],
    'initialValue': '1989',
    'plotlycommand': 'animate',
    'values': 'Year',
    'visible': True
}

figure['layout']['updatemenus'] = [
    {
        'buttons': [
            {
                'args': [None, {'frame': {'duration': 500, 'redraw': False},
                         'fromcurrent': True, 'transition': {'duration': 300, 'easing': 'quadratic-in-out'}}],
                'label': 'Play',
                'method': 'animate'
            },
            {
                'args': [[None], {'frame': {'duration': 0, 'redraw': False}, 'mode': 'immediate',
                'transition': {'duration': 0}}],
                'label': 'Pause',
                'method': 'animate'
            }
        ],
        'direction': 'left',
        'pad': {'r': 10, 't': 87},
        'showactive': False,
        'type': 'buttons',
        'x': 0.1,
        'xanchor': 'right',
        'y': 0,
        'yanchor': 'top'
    }
]

# %%
sliders_dict = {
    'active': 0,
    'yanchor': 'top',
    'xanchor': 'left',
    'currentvalue': {
        'font': {'size': 20},
        'prefix': 'Year:',
        'visible': True,
        'xanchor': 'right'
    },
    'transition': {'duration': 300, 'easing': 'cubic-in-out'},
    'pad': {'b': 10, 't': 50},
    'len': 0.9,
    'x': 0.1,
    'y': 0,
    'steps': []
}

# %%
custom_colors = {
    'NSW': 'rgb(171, 99, 250)',
    'ACT': 'rgb(230, 99, 250)',
    'WA': 'rgb(99, 110, 250)',
    'SA': 'rgb(25, 211, 243)',
    'NT': 'rgb(9, 255, 255)',
    'QLD': 'rgb(50, 170, 255)',
    'TAS': 'rgb(20, 198, 250)',
    'VIC': 'rgb(9, 200, 200)' 
}

col_name_template = '{Year}_{state}_{header}_gapminder_grid'
year = 1989
for state in state:
    data_dict = {
        'xsrc': grid.get_column_reference(col_name_template.format(
            year=year, state=state, header='Age'
        )),
        'ysrc': grid.get_column_reference(col_name_template.format(
            year=year, state=state, header='Gender'
        )),
        'mode': 'markers',
        'textsrc': grid.get_column_reference(col_name_template.format(
            year=year, state=state, header='Year'
        )),
        'marker': {
            'sizemode': 'area',
            'sizeref': 200000,
            'sizesrc': grid.get_column_reference(col_name_template.format(
                 year=year, state=state, header='pop'
            )),
            'color': custom_colors[continent]
        },
        'name': state
    }
    figure['data'].append(data_dict)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-90-1fdf3d2d2740> in <module>()
#      14 for state in state:
#      15     data_dict = {
# ---> 16         'xsrc': grid.get_column_reference(col_name_template.format(
#      17             year=year, state=state, header='Age'
#      18         )),
#
# AttributeError: 'Grid' object has no attribute 'get_column_reference'

# %%
for year in years:
    frame = {'data': [], 'name': str(year)}
    for continent in continents:
        data_dict = {
            'xsrc': grid.get_column_reference(col_name_template.format(
                year=year, continent=continent, header='lifeExp'
            )),
            'ysrc': grid.get_column_reference(col_name_template.format(
                year=year, continent=continent, header='gdpPercap'
            )),
            'mode': 'markers',
            'textsrc': grid.get_column_reference(col_name_template.format(
                year=year, continent=continent, header='country'
                )),
            'marker': {
                'sizemode': 'area',
                'sizeref': 200000,
                'sizesrc': grid.get_column_reference(col_name_template.format(
                    year=year, continent=continent, header='pop'
                )),
                'color': custom_colors[continent]
            },
            'name': continent
        }
        frame['data'].append(data_dict)

    figure['frames'].append(frame)
    slider_step = {'args': [
        [year],
        {'frame': {'duration': 300, 'redraw': False},
         'mode': 'immediate',
       'transition': {'duration': 300}}
     ],
     'label': year,
     'method': 'animate'}
    sliders_dict['steps'].append(slider_step)

figure['layout']['sliders'] = [sliders_dict]

py.icreate_animations(figure, 'gapminder_example'+str(time.time()))

# %%
crash_data["Crash_Type"].value_counts().plot(kind="bar")

# %%
crash_data["Speed_Limit"].value_counts().plot(kind="line")

# %%
world = gp.read_file(gp.datasets.get_path('naturalearth_lowres'))

# %%
cities = gp.read_file(gp.datasets.get_path('naturalearth_cities'))

# %%
world.head()
# Out:
#        continent  gdp_md_est  \
# 0           Asia     22270.0
# 1         Africa    110300.0
# 2         Europe     21810.0
# 3           Asia    184300.0
# 4  South America    573900.0
#
#                                             geometry iso_a3  \
# 0  POLYGON ((61.21081709172574 35.65007233330923,...    AFG
# 1  (POLYGON ((16.32652835456705 -5.87747039146621...    AGO
# 2  POLYGON ((20.59024743010491 41.85540416113361,...    ALB
# 3  POLYGON ((51.57951867046327 24.24549713795111,...    ARE
# 4  (POLYGON ((-65.50000000000003 -55.199999999999...    ARG
#
#                    name     pop_est
# 0           Afghanistan  28400000.0
# 1                Angola  12799293.0
# 2               Albania   3639453.0
# 3  United Arab Emirates   4798491.0
# 4             Argentina  40913584.0

# %%
world.plot();

# %%
australia = world[world.name == "Australia"]
australia.plot()

# %%
shp_file_name = "ne_10m_admin_1_states_provinces.shp"
zip_file_name = "ne_10m_admin_1_states_provinces.zip"
web_file_path = ("http://www.naturalearthdata.com/http//www.naturalearthdata.com/download/10m/cultural/ne_10m_admin_1_states_provinces.zip")

# %%
def unzip_zipfile(zipped_file_path, put_it_here="."):
    import zipfile
    zip_of_states = zipfile.ZipFile(zipped_file_path, 'r')
    zip_of_states.extractall(put_it_here)
    zip_of_states.close()

# %%
if os.path.isfile(shp_file_name):
    print("loading from file")
else:
    if os.path.isfile(zip_file_name):
        print("unzipping")
        unzip_zipfile(zip_file_name)
    else:
        import requests
        print("loading from the internet")
        page = requests.get(web_file_path)
        with open(zip_file_name, 'wb') as z:
            z.write(page.content)
        unzip_zipfile(zip_file_name)

print("done")
# Out:
# loading from file
# done

# %%
bounds = gp.GeoDataFrame.from_file(shp_file_name)
bounds(bounds.index[167:178])
bounds.head(180)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-61-3b27308a6c46> in <module>()
#       1 bounds = gp.GeoDataFrame.from_file(shp_file_name)
# ----> 2 bounds(bounds.index[167:178])
#       3 bounds.head(180)
#
# TypeError: 'GeoDataFrame' object is not callable

# %%
bounds.plot()
